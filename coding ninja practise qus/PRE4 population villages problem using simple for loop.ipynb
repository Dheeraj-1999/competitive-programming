# %%
population = list(map(int, input("Enter a multiple value: ").split()))
villages = int(len(population))
for i in range(int(len(population)/2)):
     print(int((population[i]+population[villages-i-1])/10),((population[i]+population[villages-i-1])%10))
# Out:
# Enter a multiple value: 26 96 18 24 87 51 44 86 75 32
# 5 8
# 17 1
# 10 4
# 6 8
# 13 8
